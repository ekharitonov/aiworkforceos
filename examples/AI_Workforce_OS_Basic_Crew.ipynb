# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {"provenance": []},
    "kernelspec": {"name": "python3", "display_name": "Python 3"}
  },
  "cells": [
    {
      "cell_type": "markdown",
      "source": ["# 🤖 AI Workforce OS — Basic Crew Example\n\n**Website:** [aiworkforceos.org](https://aiworkforceos.org)"],
      "metadata": {}
    },
    {
      "cell_type": "code",
      "source": ["!pip install -q crewai crewai-tools"],
      "metadata": {},
      "execution_count": null,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": ["from crewai import Agent, Task, Crew\n\nagent = Agent(\n    role='Research Analyst',\n    goal='Find information',\n    backstory='Expert researcher'\n)\n\ntask = Task(\n    description='Research benefits of human-AI teams',\n    expected_output='Summary',\n    agent=agent\n)\n\ncrew = Crew(agents=[agent], tasks=[task])\nprint('Crew ready!')"],
      "metadata": {},
      "execution_count": null,
      "outputs": []
    }
  ]
}
